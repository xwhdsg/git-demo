# %% [markdown]
# <a href="https://colab.research.google.com/github/xwhdsg/git-demo/blob/branch1/%E6%8A%A5%E8%A1%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 第一步：安装依赖

# %%
#%%capture  # 这是一个 Jupyter Notebook 的魔法命令，用于隐藏命令的输出，让笔记本界面更整洁。

# 安装 unsloth 包。unsloth 是一个用于微调大型语言模型（LLM）的工具，可以让模型运行更快、占用更少内存。
# !pip install unsloth

# 卸载当前已安装的 unsloth 包（如果已安装），然后从 GitHub 的源代码安装最新版本。
# 这样可以确保我们使用的是最新功能和修复。
# !pip uninstall unsloth -y && pip install --upgrade --no-cache-dir --no-deps git+https://github.com/unslothai/unsloth.git

# 安装 bitsandbytes 和 unsloth_zoo 包。
# bitsandbytes 是一个用于量化和优化模型的库，可以帮助减少模型占用的内存。
# unsloth_zoo 可能包含了一些预训练模型或其他工具，方便我们使用。
# !pip install bitsandbytes unsloth_zoo
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.0/59.0 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.7/346.7 kB 29.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 MB 19.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.8/506.8 kB 47.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 149.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 564.7/564.7 kB 52.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.4/270.4 kB 27.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.2/117.2 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.6/132.6 kB 14.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 MB 19.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 130.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# # 第二步：加载预训练模型

# %%
from unsloth import FastLanguageModel  # 导入FastLanguageModel类，用来加载和使用模型
import torch  # 导入torch工具，用于处理模型的数学运算

max_seq_length = 2048  # 设置模型处理文本的最大长度，相当于给模型设置一个“最大容量”
dtype = None  # 设置数据类型，让模型自动选择最适合的精度
load_in_4bit = True  # 使用4位量化来节省内存，就像把大箱子压缩成小箱子

# 加载预训练模型，并获取tokenizer工具
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name="unsloth/DeepSeek-R1-Distill-Llama-8B",  # 指定要加载的模型名称
    max_seq_length=max_seq_length,  # 使用前面设置的最大长度
    dtype=dtype,  # 使用前面设置的数据类型
    load_in_4bit=load_in_4bit,  # 使用4位量化
    # token="hf_...",  # 如果需要访问授权模型，可以在这里填入密钥
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# WARNING:torchao:Skipping import of cpp extensions due to incompatible torch version 2.8.0+cu126 for torchao version 0.14.1             Please see https://github.com/pytorch/ao/issues/2919 for more info
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2025.10.9: Fast Llama patching. Transformers: 4.56.2.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.8.0+cu126. CUDA: 7.5. CUDA Toolkit: 12.6. Triton: 3.4.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.32.post2. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/5.96G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/236 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# ...

# %% [markdown]
# # 第三步：微调前测试

# %%
prompt_style = """以下是描述任务的指令，以及提供进一步上下文的输入。
请写出一个适当完成请求的回答。
在回答之前，请仔细思考问题，并创建一个逻辑连贯的思考过程，以确保回答准确无误。

### 指令：
你是一位精通管理财务报表的财务人员。
请回答以下
报表相关问题。

### 问题：
{}

### 回答：
<think>{}"""
# 定义提示风格的字符串模板，用于格式化问题

question = "2025年第一季度，想了解公司这一季度的财政走势"
# 定义具体的报表问题

# %%
FastLanguageModel.for_inference(model)
# 准备模型以进行推理

inputs = tokenizer([prompt_style.format(question, "")], return_tensors="pt").to("cuda")
# 使用 tokenizer 对格式化后的问题进行编码，并移动到 GPU

outputs = model.generate(
    input_ids=inputs.input_ids,
    attention_mask=inputs.attention_mask,
    max_new_tokens=1200,
    use_cache=True,
)
# 使用模型生成回答

response = tokenizer.batch_decode(outputs)
# 解码模型生成的输出为可读文本

print(response[0])
# 打印生成的回答部分
# Out:
# <｜begin▁of▁sentence｜>以下是描述任务的指令，以及提供进一步上下文的输入。
# 请写出一个适当完成请求的回答。
# 在回答之前，请仔细思考问题，并创建一个逻辑连贯的思考过程，以确保回答准确无误。
#
# ### 指令：
# 你是一位精通管理财务报表的财务人员。
# 请回答以下算命问题。
#
# ### 问题：
# 2025年第一季度，想了解公司这一季度的财政走势
#
# ### 回答：
# <think>
# 嗯，我现在需要帮助用户分析公司2025年第一季度的财务走势。首先，我应该明确用户的具体需求是什么。用户可能是一位财务人员或者管理层，想要了解公司在这季度的财务状况，以便做出决策或者调整策略。
#
# 接下来，我要考虑从哪些方面来分析财务报表。通常，财务分析包括资产负债表、利润表和现金流量表。资产负债表可以展示公司的资产和负债情况，了解公司的财务健康状况；利润表则能反映公司的收入和利润情况，帮助评估盈利能力；现金流量表则显示现金流入和流出，了解公司的现金管理能力。
#
# 然后，我应该思考用户可能关心的具体问题。比如，资产负债表方面，公司的资产是否健康，负债是否可控；利润表方面，收入是否增长，利润率如何，成本控制如何；现金流量表方面，现金流是否充裕，是否有足够的 liquidity 来覆盖运营和投资需求。
#
# 此外，用户可能还会关心一些指标，比如ROE、净利润率、现金流的季节性波动等。这些指标可以帮助用户全面评估公司的财务状况。
#
# 我还需要考虑行业背景和公司内部的具体情况。比如，如果公司属于制造业，可能需要关注原材料成本和生产成本；如果属于服务业，可能要关注运营成本和服务收入。了解公司的主营业务和市场环境，才能更好地分析财务数据。
#
# 另外，季度数据可能会受到季节性因素的影响，比如第一季度通常是公司运营的一个低谷期，销售收入可能较低，利润也可能较为有限。因此，用户需要与此相比较，分析公司是否能够保持稳健的财务表现，或者是否有潜在的风险。
#
# 最后，我应该建议用户具体的分析步骤，比如数据收集、数据整理、比对分析、趋势预测以及与预期目标的对比。这样用户可以系统地分析财务报表，找出问题所在，制定相应的改进措施或发展策略。
#
# ...
